# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(-3,3,01.1)
y1=np.sin(x)
y2=np.cos(x)

# %%
# %matplotlib inline
plt.figure()
plt.plot(x,y1,'ro-',label='sin')
plt.plot(x,y2,'b--',label='cos')
plt.legend()
plt.title('aa')
ax=plt.gca()

# %%
plt.figure?

# %%
fig=plt.figure(num=4,figsize=(8,5))

# %%
fig.subplots_adjust(wspace=0.2,hspace=0.3)
ax1=fig.add_subplot(2,1,1)
ax2=fig.add_subplot(2,1,2)
ax1.plot(x,y1,'ro-',label='sin')
plt.title('sin')
plt.show()
ax2.plot(x,y2,'bo--',label='cos')
plt.title('cos')
plt.show()

# %%
fig.plot(a,y1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-d15b339270fd> in <module>()
# ----> 1 fig.plot(a,y1)
#
# AttributeError: 'Figure' object has no attribute 'plot'

# %%
print(fig)
print(ax1)
# Out:
# Figure(432x288)
# AxesSubplot(0.125,0.536818;0.775x0.343182)
